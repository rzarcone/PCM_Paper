# %%
import numpy as np
import pandas as pd
from Jesse_Funcs import blahut
import matplotlib.pyplot as plt
# %matplotlib inline  
data = pd.read_pickle('Data/RRAM_data.pkl')

# %%
plt.scatter(data['V'],np.log10(data['R']))

# %%
752*376
# Out:
# 282752

# %%
6633*8
# Out:
# 53064

# %%
(752*376)/(6633*8)
# Out:
# 5.328508970300015

# %%
2.68
